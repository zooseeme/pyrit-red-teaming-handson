# %% [markdown]
# # Lab 0: Validate Endpoint
#
# この Notebook では、講師から共有された OpenAI 互換エンドポイントへ接続できることを確認します。

# %%
from helpers.handson_utils import print_env_summary

print_env_summary()

# %%
from helpers.handson_utils import chat_once

messages = [
    {"role": "system", "content": "You are a concise workshop assistant."},
    {"role": "user", "content": "PyRIT を一文で説明してください。"},
]

response = chat_once(messages)
print(response)

# %% [markdown]
# 応答が返れば準備完了です。エラーが出る場合は `.env` の 3 つの値を確認してください。
